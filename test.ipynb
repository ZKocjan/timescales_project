# %%
import numpy as np
import matplotlib.pyplot as plt 
import warnings
import sys, os
import yt

from art_tools.tracers import read_tracers
import tools.general_functions as gf
import tools.patches_functions as paf
import tools.plotting_functions as pf
import tools.adding_fields as af

def blockPrint():
    sys.stdout = open(os.devnull, 'w')

warnings.filterwarnings("ignore")

# %%
sim_names = ['ngc300rt-a10e0.03']
outputs = ['1383','1400','1418','1435']

# %%
paf.gather_data(sim_names[0], outputs, 1)
# Out:
# output nr: 1383
# Read 2008395 tracers from /n/nyx2/zkocjan/ART_outputs/ngc300rt-a10e0.03/outputs/tracers_001382. Total time 1.120287 s
# Read 2008395 tracers from /n/nyx2/zkocjan/ART_outputs/ngc300rt-a10e0.03/outputs/tracers_001383. Total time 1.037528 s
# Read 2008395 tracers from /n/nyx2/zkocjan/ART_outputs/ngc300rt-a10e0.03/outputs/tracers_001384. Total time 1.038924 s
# Read 2008395 tracers from /n/nyx2/zkocjan/ART_outputs/ngc300rt-a10e0.03/outputs/tracers_001383. Total time 1.122857 s
# output nr: 1400
# Read 2008395 tracers from /n/nyx2/zkocjan/ART_outputs/ngc300rt-a10e0.03/outputs/tracers_001399. Total time 1.050336 s
# Read 2008395 tracers from /n/nyx2/zkocjan/ART_outputs/ngc300rt-a10e0.03/outputs/tracers_001400. Total time 1.065904 s
# Read 2008395 tracers from /n/nyx2/zkocjan/ART_outputs/ngc300rt-a10e0.03/outputs/tracers_001401. Total time 1.067022 s
# Read 2008395 tracers from /n/nyx2/zkocjan/ART_outputs/ngc300rt-a10e0.03/outputs/tracers_001400. Total time 0.985902 s
# ...

# %%
pf.plotting(sim_names[0], property_name="tau_dep", binz = 10, alpha = 0.1)
